# %%
import cProfile
from mwprojekt.traffic import traffic_computation

# %%
cProfile.run("traffic_computation('../data/','03.02.2021',4)")
# Out:
#          588479 function calls (562111 primitive calls) in 0.434 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         8    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(append)
#        16    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(argsort)
#        10    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(array_equal)
#        20    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(atleast_2d)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(bincount)
#        32    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(can_cast)
#        52    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(concatenate)
#        72    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(copyto)
# ...
